# %% [markdown]
# # 20200826 - RNA, monosome and monosome TE fold changes of GIGYF2/EIF4E2 targets

# %%
import pandas as pd
import numpy as np
import math

# %%
def log_trans(x):
    try:
        return math.log(x, 10)
    except:
        return float('NaN')

# %% [markdown]
# Import Colombo et al. NMD targets (my own computations)

# %%
import pandas as pd
import pandas as pd

colombo_p_values = pd.read_csv('../4_20200809_NMD_target_calls/20200809_all_tx_colombo_NMD_meta_pvalues.tsv', sep = '\t')
colombo_p_values.sort_values(by=['meta_meta'], inplace=True)

# %% [markdown]
# Import and combine xtail analysis results

# %%
#import and concatenate data
import pandas as pd
import numpy as np
import math
import os
columns = ['tx_id','mRNA_log2FC','RPF_log2FC','log2FC_TE_v1','pvalue_v1','nontargeting_log2TE','perturbation_log2TE','log2FC_TE_v2','pvalue_v2','log2FC_TE_final','pvalue_final','pvalue.adjust','dataset']
all_xtail = []

for file_name in os.listdir('../7_20200823_xtail_analysis/2020823_xtail_results/'):
    if file_name.endswith('tsv') and not file_name.startswith('.'):
        sample_name = file_name[6:-4]
        df = pd.read_csv(os.path.join('../7_20200823_xtail_analysis/2020823_xtail_results/', file_name), sep='\t')
        df['dataset'] = sample_name
        df.columns = columns
        all_xtail.append(df)

combined_xtail_results = pd.concat(all_xtail, sort=False)

# %% [markdown]
# Plot mRNA and monosome and disome fold changes

# %%
#set up plotting
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import scipy.stats as stats
import numpy as np
plt.rcParams['pdf.fonttype'] = 42 #leaves most text as actual text in PDFs, not outlines
# Say, "the default sans-serif font is arial"
mpl.rcParams['font.sans-serif'] = "Arial"
# Then, "ALWAYS use sans-serif fonts"
mpl.rcParams['font.family'] = "sans-serif"
##plot CDF or mRNA RPKMs
black = (0,0,0)
gray = (0.5,0.5,0.5)
orange = (230/255.0,159/255.0,0)
skyBlue = (86/255.0,180/255.0,233/255.0)
bluishGreen = (0,158/255.0,115/255.0)
yellow = (240/255.0,228/255.0,66/255.0)
blue = (0,114/255.0,178/255.0)
vermillion = (213/255.0,94/255.0,0)
reddishPurple = (204/255.0,121/255.0,167/255.0)
colors = [blue, orange, bluishGreen, black, skyBlue, vermillion, reddishPurple, yellow]
rainbow = [black, vermillion, orange, bluishGreen, blue, reddishPurple, 'violet']

# %%
import sys
pipeline_dir = '/home/boris/analysis_pipelines/ribo_seq/'
if pipeline_dir not in sys.path:
    sys.path.append(pipeline_dir)
import ribo_utils

# %%
comprehensive_gtf_data = ribo_utils.gtf_data('../20200715_orfquant/orfquant_tx_sets/superset_stops_collapsed.gtf')

# %%
"""
GENCODE's definition of nonsense_mediated_decay
If the coding sequence (following the appropriate reference) of a transcript finishes >50bp
from a downstream splice site then it is tagged as NMD. If the variant does not cover the 
full reference coding sequence then it is annotated as NMD if NMD is unavoidable 
i.e. no matter what the exon structure of the missing portion is the transcript will be subject to NMD.
"""
def get_nmd_status_any(x):
    if '|' in x:
        return any([get_nmd_status_any(tx) for tx in x.split('|')])
    return sorted(comprehensive_gtf_data.transcript_to_entries[x])[0].get_value('transcript_type') == 'nonsense_mediated_decay'

def get_nmd_status_all(x):
    if '|' in x:
        return all([get_nmd_status_all(tx) for tx in x.split('|')])
    return sorted(comprehensive_gtf_data.transcript_to_entries[x])[0].get_value('transcript_type') == 'nonsense_mediated_decay'

def get_gene_id(x):
    if '|' in x:
        return get_gene_id(x.split('|')[0])
    return comprehensive_gtf_data.tx_to_genes[x]

def get_gene_name(x):
    if '|' in x:
        return get_gene_name(x.split('|')[0])
    return comprehensive_gtf_data.tx_to_gene_names[x]

def log_trans(x):
    try:
        return math.log(x, 10)
    except:
        return float('NaN')

combined_xtail_results['has dEJC'] = combined_xtail_results['tx_id'].apply(get_nmd_status_any)
#combined_xtail_results['all have dEJC'] = combined_xtail_results['tx_id'].apply(get_nmd_status_all)

# %%
#combined_xtail_results.replace([np.inf, -np.inf], np.nan)
#combined_xtail_results=combined_xtail_results.dropna()

# %%
dataset_group = combined_xtail_results.groupby('dataset')
for dataset in combined_xtail_results['dataset'].unique():
    df = dataset_group.get_group(dataset)
    df_in_columbo = df[df['tx_id'].isin(colombo_p_values['tx_id'])]
    print(dataset, len(df), len(df_in_columbo))
#df_in_columbo
# Out:
# ('eIF4E2_in_SMG1i_mono_RNA', 10849, 9804)
# ('SMG1i_mono_RNA_old', 10312, 9755)
# ('SMG1i_mono_RNA', 10108, 9278)
# ('GIGYF2_in_DMSO_di_RNA', 553, 514)
# ('GIGYF2_mono_RNA_old', 9926, 9406)
# ('eIF4E2_mono_RNA_old', 10066, 9534)
# ('GIGYF2_SMG1i_v_WT_mono_RNA', 10906, 9859)
# ('eIF4E2_in_DMSO_mono_RNA', 10724, 9785)
# ('SMG1i_di_RNA', 497, 462)
# ('GIGYF2_SMG1i_v_WT_di_RNA', 578, 536)
# ('eIF4E2_in_DMSO_di_RNA', 656, 609)
# ('eIF4E2_in_SMG1i_di_RNA', 476, 439)
# ('eIF4E2_SMG1i_v_WT_di_RNA', 465, 429)
# ('GIGYF2_in_SMG1i_di_RNA', 572, 531)
# ('GIGYF2_in_SMG1i_mono_RNA', 10905, 9824)
# ('GIGYF2_in_DMSO_mono_RNA', 10304, 9469)
# ('eIF4E2_SMG1i_v_WT_mono_RNA', 10814, 9839)

# %%
#plot fold changes

variables_to_plot = ['mRNA_log2FC', 'RPF_log2FC', 'log2FC_TE_final']
p_values = [1, 0.1, 0.05, 0.01, 0.001, 0.0001]

dataset_group = combined_xtail_results.groupby('dataset')
#dataset = combined_xtail_results['dataset'].unique()[0]
#df = dataset_group.get_group(dataset)
#tx_overlap = set(df.dropna()['tx_id'])
#for dataset in combined_xtail_results['dataset'].unique():
#    df = dataset_group.get_group(dataset)
#    tx_overlap = tx_overlap.intersection(set(df.dropna()['tx_id']))

plot_colors = [gray, bluishGreen, blue, black, reddishPurple, vermillion]


plot_index = 1
num_plots_wide = 3
num_plots_high = 1
fig = plt.figure(figsize=(6*num_plots_wide, 3*num_plots_high))


for variable_to_plot in variables_to_plot:
    color_index = 0
    plot = fig.add_subplot(num_plots_high, num_plots_wide, plot_index)
    box_data = []
    box_colors = []
    box_labels = []
    for dataset in ['SMG1i_mono_RNA']:  
        df = dataset_group.get_group(dataset)
        #df = df[df['tx_id'].isin(tx_overlap)]
        all_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=p_values[0]]
        all_df = df[df['tx_id'].isin(all_colombo_tx['tx_id'])].dropna()
        box_data.append(all_df[variable_to_plot].dropna())
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s all_with_p (%d)' %(dataset, len(all_df[variable_to_plot])))

        for p in p_values[1:]:
            colombo_nmd_targets = colombo_p_values[colombo_p_values['meta_meta']<=p]
            nmd_df = df[df['tx_id'].isin(colombo_nmd_targets['tx_id'])].dropna()
            mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_df[variable_to_plot], alternative='two-sided')
            box_data.append(nmd_df[variable_to_plot])
            box_colors.append(plot_colors[color_index])
            box_labels.append('%s NMD %.4f (%d, %.3g)' %(dataset, p, len(nmd_df[variable_to_plot]), mwp))

        for p in p_values:
            colombo_ejc_nmd_targets = colombo_p_values[(colombo_p_values['meta_meta']<=p) & 
                                                       (colombo_p_values['GENCODE nmd annotation'])]
            nmd_df = df[df['tx_id'].isin(colombo_ejc_nmd_targets['tx_id'])].dropna()
            mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_df[variable_to_plot], alternative='two-sided')
            box_data.append(nmd_df[variable_to_plot])
            box_colors.append(plot_colors[color_index])
            box_labels.append('%s EJC NMD %.4f (%d, %.3g)' %(dataset, p, len(nmd_df[variable_to_plot]), mwp))

        color_index+=1
    bp = plot.boxplot(box_data, labels=box_labels, patch_artist=True, showfliers=False, notch=True,)

    # fill with colors
    i = 0
    for patch, color in zip(bp['boxes'], box_colors):
        patch.set_facecolor(color)
        patch.set(linewidth=0)
        #if i%3 > 0:
        #    patch.set_alpha(0.5)
        #if i%3 == 2:
        #    patch.set_hatch('////')
        #i += 1
    #draw line at median
    #for i in range(0,15, 3):
    #    mean = np.median(box_data[i])
    #    plot.hlines(mean, i+0.75, i+3.25, linestyles='dashed', colors=black, linewidth=1, zorder=10)
    plot.hlines(0, 0, 12, linestyles='dashed', colors=black, linewidth=1, zorder=10)

    #plot.set_xlabel(variable_to_plot)
    plot.set_ylabel(variable_to_plot, fontsize=15)
    #plot.set_title('NMD p = %.3g' %(p))
    #plot.set_ylim(0, 1.01)
    #if variable_to_plot == 'log2FC_TE_final':
    #    plot.set_xlim(-2, 2)
    #else:
    #plot.set_xlim(-1, 1)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    plt.xticks(rotation=45, ha='right')
    plot_index += 1
    #lg=plot.legend(loc=4,prop={'size':12}, labelspacing=0.2)
    #lg.draw_frame(False)
#plt.subplots_adjust(wspace = 0.3)
#plt.tight_layout()
plt.savefig('E.8.019_20200823_NMD_SMG1i_boxplots.pdf', transparent='True', format='pdf', bbox_inches='tight')

# %%
#plot fold changes

variables_to_plot = ['mRNA_log2FC', 'RPF_log2FC', 'log2FC_TE_final']
p_values = [1, 0.1, 0.05, 0.01, 0.001, 0.0001]

dataset_group = combined_xtail_results.groupby('dataset')
#dataset = combined_xtail_results['dataset'].unique()[0]
#df = dataset_group.get_group(dataset)
#tx_overlap = set(df.dropna()['tx_id'])
#for dataset in combined_xtail_results['dataset'].unique():
#    df = dataset_group.get_group(dataset)
#    tx_overlap = tx_overlap.intersection(set(df.dropna()['tx_id']))

plot_colors = [gray, bluishGreen, blue, black, reddishPurple, vermillion]


plot_index = 1
num_plots_wide = 3
num_plots_high = 1
fig = plt.figure(figsize=(6*num_plots_wide, 3*num_plots_high))


for variable_to_plot in variables_to_plot:
    color_index = 0
    plot = fig.add_subplot(num_plots_high, num_plots_wide, plot_index)
    box_data = []
    box_colors = []
    box_labels = []
    for dataset in ['SMG1i_mono_RNA_old']:  
        df = dataset_group.get_group(dataset)
        #df = df[df['tx_id'].isin(tx_overlap)]
        all_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=p_values[0]]
        all_df = df[df['tx_id'].isin(all_colombo_tx['tx_id'])].dropna()
        box_data.append(all_df[variable_to_plot])
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s all_with_p (%d)' %(dataset, len(all_df[variable_to_plot])))

        for p in p_values[1:]:
            colombo_nmd_targets = colombo_p_values[colombo_p_values['meta_meta']<=p]
            nmd_df = df[df['tx_id'].isin(colombo_nmd_targets['tx_id'])].dropna()
            mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_df[variable_to_plot], alternative='two-sided')
            box_data.append(nmd_df[variable_to_plot])
            box_colors.append(plot_colors[color_index])
            box_labels.append('%s NMD %.4f (%d, %.3g)' %(dataset, p, len(nmd_df[variable_to_plot]), mwp))

        for p in p_values:
            colombo_ejc_nmd_targets = colombo_p_values[(colombo_p_values['meta_meta']<=p) & 
                                                       (colombo_p_values['GENCODE nmd annotation'])]
            nmd_df = df[df['tx_id'].isin(colombo_ejc_nmd_targets['tx_id'])].dropna()
            mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot], nmd_df[variable_to_plot], alternative='two-sided')
            box_data.append(nmd_df[variable_to_plot])
            box_colors.append(plot_colors[color_index])
            box_labels.append('%s EJC NMD %.4f (%d, %.3g)' %(dataset, p, len(nmd_df[variable_to_plot]), mwp))

        color_index+=1
    bp = plot.boxplot(box_data, labels=box_labels, patch_artist=True, showfliers=False, notch=True,)

    # fill with colors
    i = 0
    for patch, color in zip(bp['boxes'], box_colors):
        patch.set_facecolor(color)
        patch.set(linewidth=0)
        #if i%3 > 0:
        #    patch.set_alpha(0.5)
        #if i%3 == 2:
        #    patch.set_hatch('////')
        #i += 1
    #draw line at median
    #for i in range(0,15, 3):
    #    mean = np.median(box_data[i])
    #    plot.hlines(mean, i+0.75, i+3.25, linestyles='dashed', colors=black, linewidth=1, zorder=10)
    plot.hlines(0, 0, 12, linestyles='dashed', colors=black, linewidth=1, zorder=10)

    #plot.set_xlabel(variable_to_plot)
    plot.set_ylabel(variable_to_plot, fontsize=15)
    #plot.set_title('NMD p = %.3g' %(p))
    #plot.set_ylim(0, 1.01)
    #if variable_to_plot == 'log2FC_TE_final':
    #    plot.set_xlim(-2, 2)
    #else:
    #plot.set_xlim(-1, 1)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    plt.xticks(rotation=45, ha='right')
    plot_index += 1
    #lg=plot.legend(loc=4,prop={'size':12}, labelspacing=0.2)
    #lg.draw_frame(False)
#plt.subplots_adjust(wspace = 0.3)
#plt.tight_layout()
plt.savefig('E.8.019_20200823_NMD_SMG1i_old_boxplots.pdf', transparent='True', format='pdf', bbox_inches='tight')

# %%
#plot fold changes

variables_to_plot = ['mRNA_log2FC', 'RPF_log2FC', 'log2FC_TE_final']
p_values = [1, 0.1, 0.05, 0.01, 0.001, 0.0001]

dataset_group = combined_xtail_results.groupby('dataset')
#dataset = combined_xtail_results['dataset'].unique()[0]
#df = dataset_group.get_group(dataset)
#tx_overlap = set(df.dropna()['tx_id'])
#for dataset in combined_xtail_results['dataset'].unique():
#    df = dataset_group.get_group(dataset)
#    tx_overlap = tx_overlap.intersection(set(df.dropna()['tx_id']))

plot_colors = [gray, bluishGreen, blue, black, reddishPurple, vermillion]


for dataset in combined_xtail_results['dataset'].unique():  
    plot_index = 1
    num_plots_wide = 3
    num_plots_high = 1
    fig = plt.figure(figsize=(6*num_plots_wide, 3*num_plots_high))
    for variable_to_plot in variables_to_plot:
        color_index = 0
        plot = fig.add_subplot(num_plots_high, num_plots_wide, plot_index)
        box_data = []
        box_colors = []
        box_labels = []
        df = dataset_group.get_group(dataset)
        #df = df[df['tx_id'].isin(tx_overlap)]
        all_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=p_values[0]]
        all_df = df[df['tx_id'].isin(all_colombo_tx['tx_id'])].dropna()
        box_data.append(all_df[variable_to_plot].dropna())
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s all_with_p (%d)' %(dataset, len(all_df[variable_to_plot])))

        for p in p_values[1:]:
            colombo_nmd_targets = colombo_p_values[colombo_p_values['meta_meta']<=p]
            nmd_df = df[df['tx_id'].isin(colombo_nmd_targets['tx_id'])].dropna()
            mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_df[variable_to_plot].dropna(), alternative='two-sided')
            box_data.append(nmd_df[variable_to_plot].dropna())
            box_colors.append(plot_colors[color_index])
            box_labels.append('%s NMD %.4f (%d, %.3g)' %(dataset, p, len(nmd_df[variable_to_plot].dropna()), mwp))

        for p in p_values:
            colombo_ejc_nmd_targets = colombo_p_values[(colombo_p_values['meta_meta']<=p) & 
                                                       (colombo_p_values['GENCODE nmd annotation'])]
            nmd_df = df[df['tx_id'].isin(colombo_ejc_nmd_targets['tx_id'])].dropna()
            mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_df[variable_to_plot], alternative='two-sided')
            box_data.append(nmd_df[variable_to_plot])
            box_colors.append(plot_colors[color_index])
            box_labels.append('%s EJC NMD %.4f (%d, %.3g)' %(dataset, p, len(nmd_df[variable_to_plot].dropna()), mwp))

        color_index+=1
        bp = plot.boxplot(box_data, labels=box_labels, patch_artist=True, showfliers=False, notch=True,)

        # fill with colors
        i = 0
        for patch, color in zip(bp['boxes'], box_colors):
            patch.set_facecolor(color)
            patch.set(linewidth=0)
            #if i%3 > 0:
            #    patch.set_alpha(0.5)
            #if i%3 == 2:
            #    patch.set_hatch('////')
            #i += 1
        #draw line at median
        #for i in range(0,15, 3):
        #    mean = np.median(box_data[i])
        #    plot.hlines(mean, i+0.75, i+3.25, linestyles='dashed', colors=black, linewidth=1, zorder=10)
        plot.hlines(0, 0, 12, linestyles='dashed', colors=black, linewidth=1, zorder=10)

        #plot.set_xlabel(variable_to_plot)
        plot.set_ylabel(variable_to_plot, fontsize=15)
        #plot.set_title('NMD p = %.3g' %(p))
        #plot.set_ylim(0, 1.01)
        #if variable_to_plot == 'log2FC_TE_final':
        #    plot.set_xlim(-2, 2)
        #else:
        #plot.set_xlim(-1, 1)
        plot.spines['right'].set_visible(False)
        plot.spines['top'].set_visible(False)
        plt.xticks(rotation=45, ha='right')
        plot_index += 1
        #lg=plot.legend(loc=4,prop={'size':12}, labelspacing=0.2)
        #lg.draw_frame(False)
    #plt.subplots_adjust(wspace = 0.3)
    #plt.tight_layout()
    plt.savefig('E.8.019_20200823_NMD_%s_boxplots.pdf' % dataset, transparent='True', format='pdf', bbox_inches='tight')

# %%
#plot fold changes

variables_to_plot = ['mRNA_log2FC', 'RPF_log2FC', 'log2FC_TE_final']
p = .05

dataset_group = combined_xtail_results.groupby('dataset')
dataset = combined_xtail_results['dataset'].unique()[0]
df = dataset_group.get_group(dataset)
tx_overlap = set(df.dropna()['tx_id'])
for dataset in combined_xtail_results['dataset'].unique():
    df = dataset_group.get_group(dataset)
    tx_overlap = tx_overlap.intersection(set(df.dropna()['tx_id']))

plot_colors = [gray, bluishGreen, blue, reddishPurple, vermillion]


plot_index = 1
num_plots_wide = len(variables_to_plot)
num_plots_high = 1
fig = plt.figure(figsize=(6*num_plots_wide, 3*num_plots_high))

colombo_nmd_targets = colombo_p_values[colombo_p_values['meta_meta']<p]
for variable_to_plot in variables_to_plot:
    color_index = 0
    plot = fig.add_subplot(num_plots_high, num_plots_wide, plot_index)
    box_data = []
    box_colors = []
    box_labels = []
    reporter_data = []
    for dataset in ['SMG1i_mono_RNA', 'eIF4E2_in_DMSO_mono_RNA', 'GIGYF2_in_DMSO_mono_RNA', 
                    'eIF4E2_in_SMG1i_mono_RNA', 'GIGYF2_in_SMG1i_mono_RNA']:  
        df = dataset_group.get_group(dataset)
        #df = df[df['tx_id'].isin(tx_overlap)]
        all_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=1]
        all_df = df[df['tx_id'].isin(all_colombo_tx['tx_id'])].dropna()
        box_data.append(all_df[variable_to_plot])
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s all (%d)' %(dataset, len(all_df[variable_to_plot].dropna())))
        
        reporter_data.append(df[df['tx_id']=='UGAC_reporter'][variable_to_plot].tolist()[0])
        
        
        nmd_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=p_value]
        nmd_df = df[df['tx_id'].isin(nmd_colombo_tx['tx_id'])].dropna()
        mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_df[variable_to_plot].dropna(), alternative='two-sided')
        box_data.append(nmd_df[variable_to_plot].dropna())
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s NMD (%d, %.3g)' %(dataset, len(nmd_df[variable_to_plot].dropna()), mwp))
        
        
        nmd_colombo_ejc_tx = colombo_p_values[(colombo_p_values['meta_meta']<=p) & 
                                                       (colombo_p_values['GENCODE nmd annotation'])]
        nmd_EJC_df = df[df['tx_id'].isin(nmd_colombo_ejc_tx['tx_id'])].dropna()
        mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_EJC_df[variable_to_plot].dropna(), alternative='two-sided')
        box_data.append(nmd_EJC_df[variable_to_plot].dropna())
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s NMD w/EJC (%d, %.3g)' %(dataset, len(nmd_EJC_df[variable_to_plot].dropna()), mwp))
        color_index+=1
        
    bp = plot.boxplot(box_data, labels=box_labels, patch_artist=True, showfliers=False, notch=True,)
    
    # fill with colors
    i = 0
    for patch, color in zip(bp['boxes'], box_colors):
        patch.set_facecolor(color)
        patch.set(linewidth=0)
        if i%3 > 0:
            patch.set_alpha(0.5)
        if i%3 == 2:
            patch.set_hatch('////')
        i += 1
    #draw line at median
    for i in range(0,15, 3):
        mean = np.median(box_data[i])
        #plot.hlines(mean, i+0.75, i+3.25, linestyles='dashed', colors=black, linewidth=1, zorder=10)
    plot.hlines(0, 0, 15, linestyles='dashed', colors=black, linewidth=1, zorder=10)
    plot.scatter(range(1,16,3), reporter_data, color=skyBlue, edgecolor=blue, s=20, zorder=11)
    #plot.set_xlabel(variable_to_plot)
    plot.set_ylabel(variable_to_plot, fontsize=15)
    #plot.set_title('NMD p = %.3g' %(p))
    #plot.set_ylim(0, 1.01)
    #if variable_to_plot == 'log2FC_TE_final':
    #    plot.set_xlim(-2, 2)
    #else:
    #plot.set_xlim(-1, 1)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    plt.xticks(rotation=45, ha='right')
    plot_index += 1
    #lg=plot.legend(loc=4,prop={'size':12}, labelspacing=0.2)
    #lg.draw_frame(False)
plt.subplots_adjust(wspace = 0.3)
#plt.tight_layout()
plt.savefig('E.8.019_20200823_NMD_%.2f_EJC_boxplots_new_data.pdf' %(p), transparent='True', format='pdf', bbox_inches='tight')

# %%
#plot fold changes

variables_to_plot = ['mRNA_log2FC', 'RPF_log2FC', 'log2FC_TE_final']
p = .05

dataset_group = combined_xtail_results.groupby('dataset')
dataset = combined_xtail_results['dataset'].unique()[0]
df = dataset_group.get_group(dataset)
tx_overlap = set(df.dropna()['tx_id'])
for dataset in combined_xtail_results['dataset'].unique():
    df = dataset_group.get_group(dataset)
    tx_overlap = tx_overlap.intersection(set(df.dropna()['tx_id']))

plot_colors = [gray, bluishGreen, blue, reddishPurple, vermillion]


plot_index = 1
num_plots_wide = len(variables_to_plot)
num_plots_high = 1
fig = plt.figure(figsize=(6*num_plots_wide, 6*num_plots_high))

colombo_nmd_targets = colombo_p_values[colombo_p_values['meta_meta']<p]
for variable_to_plot in variables_to_plot:
    color_index = 0
    plot = fig.add_subplot(num_plots_high, num_plots_wide, plot_index)
    box_data = []
    box_colors = []
    box_labels = []
    reporter_data = []
    for dataset in ['SMG1i_mono_RNA', 'eIF4E2_in_DMSO_mono_RNA', 'GIGYF2_in_DMSO_mono_RNA', 
                    'eIF4E2_in_SMG1i_mono_RNA', 'GIGYF2_in_SMG1i_mono_RNA']:  
        df = dataset_group.get_group(dataset)
        #df = df[df['tx_id'].isin(tx_overlap)]
        all_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=1]
        all_df = df[df['tx_id'].isin(all_colombo_tx['tx_id'])].dropna()
        box_data.append(all_df[variable_to_plot])
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s all (%d)' %(dataset, len(all_df[variable_to_plot].dropna())))
        
        reporter_data.append(df[df['tx_id']=='UGAC_reporter'][variable_to_plot].tolist()[0])
        
        
        #nmd_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=p]
        #nmd_df = df[df['tx_id'].isin(nmd_colombo_tx['tx_id'])].dropna()
        #mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_df[variable_to_plot].dropna(), alternative='two-sided')
        #box_data.append(nmd_df[variable_to_plot].dropna())
        #box_colors.append(plot_colors[color_index])
        #box_labels.append('%s NMD (%d, %.3g)' %(dataset, len(nmd_df[variable_to_plot].dropna()), mwp))
        
        
        nmd_colombo_ejc_tx = colombo_p_values[(colombo_p_values['meta_meta']<=p) & 
                                                       (colombo_p_values['GENCODE nmd annotation'])]
        nmd_EJC_df = df[df['tx_id'].isin(nmd_colombo_ejc_tx['tx_id'])].dropna()
        mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_EJC_df[variable_to_plot].dropna(), alternative='two-sided')
        box_data.append(nmd_EJC_df[variable_to_plot].dropna())
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s NMD w/EJC (%d, %.3g)' %(dataset, len(nmd_EJC_df[variable_to_plot].dropna()), mwp))
        color_index+=1
        
    bp = plot.boxplot(box_data, labels=box_labels, patch_artist=True, showfliers=False, notch=True,)
    
    # fill with colors
    i = 0
    for patch, color in zip(bp['boxes'], box_colors):
        patch.set_facecolor(color)
        patch.set(linewidth=0)
        if i%2 > 0:
            patch.set_alpha(0.5)
        if i%2 == 1:
            patch.set_hatch('///')
        i += 1
    #draw line at median
    for i in range(0,10, 2):
        mean = np.median(box_data[i])
        #plot.hlines(mean, i+0.75, i+3.25, linestyles='dashed', colors=black, linewidth=1, zorder=10)
    plot.hlines(0, 0, 15, linestyles='dashed', colors=black, linewidth=1, zorder=10)
    plot.scatter(range(1,11,2), reporter_data, color=skyBlue, edgecolor=blue, s=20, zorder=11)
    #plot.set_xlabel(variable_to_plot)
    plot.set_ylabel(variable_to_plot, fontsize=15)
    #plot.set_title('NMD p = %.3g' %(p))
    #plot.set_ylim(0, 1.01)
    #if variable_to_plot == 'log2FC_TE_final':
    #    plot.set_xlim(-2, 2)
    #else:
    #plot.set_xlim(-1, 1)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    plt.xticks(rotation=45, ha='right')
    plot_index += 1
    #lg=plot.legend(loc=4,prop={'size':12}, labelspacing=0.2)
    #lg.draw_frame(False)
plt.subplots_adjust(wspace = 0.3)
#plt.tight_layout()
plt.savefig('E.8.019_20200823_NMD_%.2f_EJC_only_boxplots_new_data.pdf' %(p), transparent='True', format='pdf', bbox_inches='tight')

# %%
dataset_group.groups.keys()
# Out:
# ['GIGYF2_SMG1i_v_WT_mono_RNA',
#  'eIF4E2_in_DMSO_di_RNA',
#  'eIF4E2_in_SMG1i_di_RNA',
#  'SMG1i_mono_RNA_old',
#  'SMG1i_di_RNA',
#  'GIGYF2_in_DMSO_mono_RNA',
#  'SMG1i_mono_RNA',
#  'eIF4E2_in_SMG1i_mono_RNA',
#  'eIF4E2_SMG1i_v_WT_mono_RNA',
#  'GIGYF2_in_SMG1i_mono_RNA',
#  'eIF4E2_mono_RNA_old',
#  'GIGYF2_mono_RNA_old',
#  'GIGYF2_in_SMG1i_di_RNA',
#  'eIF4E2_in_DMSO_mono_RNA',
#  'GIGYF2_in_DMSO_di_RNA',
#  'eIF4E2_SMG1i_v_WT_di_RNA',
#  'GIGYF2_SMG1i_v_WT_di_RNA']

# %%
#plot fold changes

variables_to_plot = ['mRNA_log2FC', 'RPF_log2FC', 'log2FC_TE_final']
p = .05

dataset_group = combined_xtail_results.groupby('dataset')
dataset = combined_xtail_results['dataset'].unique()[0]
df = dataset_group.get_group(dataset)
tx_overlap = set(df.dropna()['tx_id'])
for dataset in combined_xtail_results['dataset'].unique():
    df = dataset_group.get_group(dataset)
    tx_overlap = tx_overlap.intersection(set(df.dropna()['tx_id']))

plot_colors = [gray, bluishGreen, blue, reddishPurple, vermillion]


plot_index = 1
num_plots_wide = len(variables_to_plot)
num_plots_high = 1
fig = plt.figure(figsize=(6*num_plots_wide, 3*num_plots_high))

colombo_nmd_targets = colombo_p_values[colombo_p_values['meta_meta']<p]
for variable_to_plot in variables_to_plot:
    color_index = 0
    plot = fig.add_subplot(num_plots_high, num_plots_wide, plot_index)
    box_data = []
    box_colors = []
    box_labels = []
    reporter_data = []
    for dataset in ['SMG1i_mono_RNA', 'eIF4E2_in_DMSO_mono_RNA', 'GIGYF2_in_DMSO_mono_RNA', 
                    'eIF4E2_SMG1i_v_WT_mono_RNA', 'GIGYF2_SMG1i_v_WT_mono_RNA']:  
        df = dataset_group.get_group(dataset)
        #df = df[df['tx_id'].isin(tx_overlap)]
        all_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=1]
        all_df = df[df['tx_id'].isin(all_colombo_tx['tx_id'])].dropna()
        box_data.append(all_df[variable_to_plot])
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s all (%d)' %(dataset, len(all_df[variable_to_plot].dropna())))
        
        reporter_data.append(df[df['tx_id']=='UGAC_reporter'][variable_to_plot].tolist()[0])
        
        
        nmd_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=p]
        nmd_df = df[df['tx_id'].isin(nmd_colombo_tx['tx_id'])].dropna()
        mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_df[variable_to_plot].dropna(), alternative='two-sided')
        box_data.append(nmd_df[variable_to_plot].dropna())
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s NMD (%d, %.3g)' %(dataset, len(nmd_df[variable_to_plot].dropna()), mwp))
        
        
        nmd_colombo_ejc_tx = colombo_p_values[(colombo_p_values['meta_meta']<=p) & 
                                                       (colombo_p_values['GENCODE nmd annotation'])]
        nmd_EJC_df = df[df['tx_id'].isin(nmd_colombo_ejc_tx['tx_id'])].dropna()
        mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_EJC_df[variable_to_plot].dropna(), alternative='two-sided')
        box_data.append(nmd_EJC_df[variable_to_plot].dropna())
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s NMD w/EJC (%d, %.3g)' %(dataset, len(nmd_EJC_df[variable_to_plot].dropna()), mwp))
        color_index+=1
        
    bp = plot.boxplot(box_data, labels=box_labels, patch_artist=True, showfliers=False, notch=True,)
    
    # fill with colors
    i = 0
    for patch, color in zip(bp['boxes'], box_colors):
        patch.set_facecolor(color)
        patch.set(linewidth=0)
        if i%3 > 0:
            patch.set_alpha(0.5)
        if i%3 == 2:
            patch.set_hatch('////')
        i += 1
    #draw line at median
    for i in range(0,15, 3):
        mean = np.median(box_data[i])
        #plot.hlines(mean, i+0.75, i+3.25, linestyles='dashed', colors=black, linewidth=1, zorder=10)
    plot.hlines(0, 0, 15, linestyles='dashed', colors=black, linewidth=1, zorder=10)
    plot.scatter(range(1,16,3), reporter_data, color=skyBlue, edgecolor=blue, s=20, zorder=11)
    #plot.set_xlabel(variable_to_plot)
    plot.set_ylabel(variable_to_plot, fontsize=15)
    #plot.set_title('NMD p = %.3g' %(p))
    #plot.set_ylim(0, 1.01)
    #if variable_to_plot == 'log2FC_TE_final':
    #    plot.set_xlim(-2, 2)
    #else:
    #plot.set_xlim(-1, 1)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    plt.xticks(rotation=45, ha='right')
    plot_index += 1
    #lg=plot.legend(loc=4,prop={'size':12}, labelspacing=0.2)
    #lg.draw_frame(False)
plt.subplots_adjust(wspace = 0.3)
#plt.tight_layout()
plt.savefig('E.8.019_20200823_NMD_%.2f_EJC_boxplots_SMG1i_full_effect_new_data.pdf' %(p), transparent='True', format='pdf', bbox_inches='tight')

# %%
df[df['tx_id']=='UGAC_reporter']
# Out:
#               tx_id  mRNA_log2FC  RPF_log2FC  log2FC_TE_v1     pvalue_v1  \
# 5647  UGAC_reporter     2.088479    2.686312      0.597612  1.874088e-19
#
#       nontargeting_log2TE  perturbation_log2TE  log2FC_TE_v2     pvalue_v2  \
# 5647            -0.801535            -0.203702      0.598079  4.576587e-14
#
#       log2FC_TE_final  pvalue_final  pvalue.adjust         dataset  has dEJC
# 5647         0.598079  4.576587e-14   1.186157e-11  SMG1i_mono_RNA     False

# %%
combined_xtail_results['dataset'].unique()
# Out:
# array(['eIF4E2_in_SMG1i_mono_RNA', 'SMG1i_mono_RNA_old', 'SMG1i_mono_RNA',
#        'GIGYF2_in_DMSO_di_RNA', 'GIGYF2_mono_RNA_old',
#        'eIF4E2_mono_RNA_old', 'GIGYF2_SMG1i_v_WT_mono_RNA',
#        'eIF4E2_in_DMSO_mono_RNA', 'SMG1i_di_RNA',
#        'GIGYF2_SMG1i_v_WT_di_RNA', 'eIF4E2_in_DMSO_di_RNA',
#        'eIF4E2_in_SMG1i_di_RNA', 'eIF4E2_SMG1i_v_WT_di_RNA',
#        'GIGYF2_in_SMG1i_di_RNA', 'GIGYF2_in_SMG1i_mono_RNA',
#        'GIGYF2_in_DMSO_mono_RNA', 'eIF4E2_SMG1i_v_WT_mono_RNA'],
#       dtype=object)

# %%
#plot fold changes

variables_to_plot = ['mRNA_log2FC', 'RPF_log2FC', 'log2FC_TE_final']
p = .05

dataset_group = combined_xtail_results.groupby('dataset')
dataset = combined_xtail_results['dataset'].unique()[0]
df = dataset_group.get_group(dataset)
tx_overlap = set(df.dropna()['tx_id'])
for dataset in combined_xtail_results['dataset'].unique():
    df = dataset_group.get_group(dataset)
    tx_overlap = tx_overlap.intersection(set(df.dropna()['tx_id']))

plot_colors = [gray, bluishGreen, blue, reddishPurple, vermillion]


plot_index = 1
num_plots_wide = len(variables_to_plot)
num_plots_high = 1
fig = plt.figure(figsize=(3.6*num_plots_wide, 3*num_plots_high))

colombo_nmd_targets = colombo_p_values[colombo_p_values['meta_meta']<p]
for variable_to_plot in variables_to_plot:
    color_index = 0
    plot = fig.add_subplot(num_plots_high, num_plots_wide, plot_index)
    box_data = []
    box_colors = []
    box_labels = []
    for dataset in ['SMG1i_mono_RNA_old', 'eIF4E2_mono_RNA_old', 'GIGYF2_mono_RNA_old']:  
        df = dataset_group.get_group(dataset)
        #df = df[df['tx_id'].isin(tx_overlap)]
        all_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=1]
        all_df = df[df['tx_id'].isin(all_colombo_tx['tx_id'])]
        box_data.append(all_df[variable_to_plot].dropna())
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s all (%d)' %(dataset, len(all_df[variable_to_plot].dropna())))
        
        nmd_colombo_tx = colombo_p_values[colombo_p_values['meta_meta']<=p]
        nmd_df = df[df['tx_id'].isin(nmd_colombo_tx['tx_id'])]
        mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_df[variable_to_plot].dropna(), alternative='two-sided')
        box_data.append(nmd_df[variable_to_plot].dropna())
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s NMD (%d, %.3g)' %(dataset, len(nmd_df[variable_to_plot].dropna()), mwp))
        
        
        nmd_colombo_ejc_tx = colombo_p_values[(colombo_p_values['meta_meta']<=p) & 
                                                       (colombo_p_values['GENCODE nmd annotation'])]
        nmd_EJC_df = df[df['tx_id'].isin(nmd_colombo_ejc_tx['tx_id'])]
        mwu, mwp = stats.mannwhitneyu(all_df[variable_to_plot].dropna(), nmd_EJC_df[variable_to_plot].dropna(), alternative='two-sided')
        box_data.append(nmd_EJC_df[variable_to_plot].dropna())
        box_colors.append(plot_colors[color_index])
        box_labels.append('%s NMD w/EJC (%d, %.3g)' %(dataset, len(nmd_EJC_df[variable_to_plot].dropna()), mwp))
        color_index+=1
        
    bp = plot.boxplot(box_data, labels=box_labels, patch_artist=True, showfliers=False, notch=True,)

    # fill with colors
    i = 0
    for patch, color in zip(bp['boxes'], box_colors):
        patch.set_facecolor(color)
        patch.set(linewidth=0)
        if i%3 > 0:
            patch.set_alpha(0.5)
        if i%3 == 2:
            patch.set_hatch('////')
        i += 1
    #draw line at median
    #for i in range(0,15, 3):
    #    mean = np.median(box_data[i])
        #plot.hlines(mean, i+0.75, i+3.25, linestyles='dashed', colors=black, linewidth=1, zorder=10)
    plot.hlines(0, 0, 9, linestyles='dashed', colors=black, linewidth=1, zorder=10)
    #plot.set_xlabel(variable_to_plot)
    plot.set_ylabel(variable_to_plot, fontsize=15)
    #plot.set_title('NMD p = %.3g' %(p))
    #plot.set_ylim(0, 1.01)
    #if variable_to_plot == 'log2FC_TE_final':
    #    plot.set_xlim(-2, 2)
    #else:
    #plot.set_xlim(-1, 1)
    plot.spines['right'].set_visible(False)
    plot.spines['top'].set_visible(False)
    plt.xticks(rotation=45, ha='right')
    plot_index += 1
    #lg=plot.legend(loc=4,prop={'size':12}, labelspacing=0.2)
    #lg.draw_frame(False)
plt.subplots_adjust(wspace = 0.3)
#plt.tight_layout()
plt.savefig('E.8.019_20200823_NMD_%.2f_EJC_boxplots_old_data.pdf' %(p), transparent='True', format='pdf', bbox_inches='tight')
